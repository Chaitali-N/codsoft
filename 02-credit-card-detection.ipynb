# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.display import Image
# !ls ../input/images

# %%
Image("/kaggle/input/images/credit card.jpeg")

# %%
Image("/kaggle/input/images/images.jpeg")

# %%
import numpy as np 
import pandas as pd
f=pd.read_csv("/kaggle/input/creditcardfraud/creditcard.csv")
print(f)

# %%
f.sample(10)

# %%
f.info()

# %%
f.head()

# %%
f.describe()

# %%
f.isnull().sum()

# %%
fraud=f[f.Class==1]
print(fraud.shape)
fraud.Amount.describe()

# %%
corr = f.corr()
corr.style.background_gradient(cmap='summer_r')

# %% [markdown]
# # Histogram plot

# %%
import matplotlib.pyplot as plt

# Define your features
features = ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# Plot each feature
for feature in features:
    plt.figure(figsize=(8,6))
    f[feature].hist(bins=30)
    plt.title(feature)
    plt.show()

# %%
f[f.Class == 0].hist(figsize = (20,20))
plt.show()

# %%
f[f.Class == 1].hist(figsize = (20,20))
plt.show()

# %% [markdown]
# # Linear Plot

# %%
from matplotlib.pyplot import figure

figure(figsize=(10, 6), dpi=80)
plt.plot(np.arange(25))
plt.title('Normal transactions')

plt.show()

# %% [markdown]
# # Bar Plot

# %%
## Amount of Fraud and Non Fraud transactions plot
import seaborn as sns
sns.set(style="whitegrid")

# Create the countplot
ax = sns.countplot(x='Class', data=f, order=[0, 1], label='Count', palette='pastel')

# Calculate the counts of E-signed and Not E-signed customers
counts = f['Class'].value_counts()

# Add text annotations for the counts
for i, count in enumerate(counts):
    ax.text(i, count, str(count), ha='center', va='bottom', fontsize=12)
# Set the title
title = "The Amount of Fraud and Non Fraud Transactions"
ax.set_title(title, size=16)
plt.title(title, size=16, pad=20)

# Show the plot
plt.show()

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (17,17))
plt.title('Credit Card Transactions features correlation plot (Pearson)')
corr = f.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Blues")
plt.show()

# %%
# Heatmap

# Calculate the correlation matrix for the dataset
corr = f.corr()

# Set the size of the heatmap figure
plt.figure(figsize=(30, 24))

# Create the heatmap using seaborn
# 'annot=True' displays the correlation values on the heatmap
# 'cmap='coolwarm'' sets the color map for the heatmap
# 'fmt='.2f'' sets the format of the displayed correlation values to have two decimal places
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
# Set the title for the heatmap
plt.title("Correlation Heatmap", fontsize=24)

# Show the heatmap
plt.show()

# %% [markdown]
# # Correlation Diagram

# %%
# Correlation Diagram

# Drop the 'Class' column from the original dataset and create a new DataFrame 'dataset_2'
dataset_2 = f.drop(columns=['Class'])

# Calculate the correlation between each column in 'dataset_2' and the 'Class' column in the original dataset
correlation_with_class = dataset_2.corrwith(f['Class'])
# Create a bar plot to visualize the correlation values with the 'Class' column
# Set the size of the figure to 16 inches (width) by 8 inches (height)
# Show grid lines in the plot for better readability
correlation_with_class.plot.bar(figsize=(16, 8), grid=True)

# Set appropriate labels and titles for the plot
plt.xlabel("Features")  # Label for the x-axis (features)
plt.ylabel("Correlation with Class")  # Label for the y-axis (correlation values)
plt.title("Correlation of Features with Class")  # Set the title for the bar plot

# Show the plot
plt.show()

# %% [markdown]
# # Sub Plot

# %%
plt.figure(figsize=(34,40)) #Outliers found but we don't treat them as it might lead to information loss

for i, col in enumerate(f.columns):
    plt.subplot(11, 3, i+1)
    sns.boxplot(f[col])
    plt.title(col)

    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(28,34))
for i, col in enumerate(f.columns):
    plt.subplot(11, 3, i+1)
    sns.kdeplot(f[col], shade=True, color='skyblue')
    plt.title(col)


plt.tight_layout()
plt.show()
